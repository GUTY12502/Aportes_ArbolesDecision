# %% [markdown]
# **Arboles de Decision by Juan Gutierrez**

# %%
#importamos las librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score

# %%
#Se carga el dataset y se muestran las primeras cinco filas
data = pd.read_csv("winequality-red.csv")
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
#Verificamos que se cargó completamente.
data.shape
# Out:
# (1599, 12)

# %%
#Mostramos las medidas estadisticas
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
#Vemos los valores nulos
data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#Realizamos un histograma donde se verifica los elementos por cada clase
plt.hist(data.quality)
# Out:
# (array([ 10.,   0.,  53.,   0., 681.,   0., 638.,   0., 199.,  18.]),
#  array([3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. , 7.5, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
#Comparamos la densidad y el grado de alcohol con la calidad de cada uno a través de un grafico de dispersión
sns.scatterplot(x = "density", y = "alcohol", hue = "quality", data = data)
# Out:
# <Axes: xlabel='density', ylabel='alcohol'>

# %%
#Dividimos el dataset, dejando las columnas predictoras y en el traget o objetivo, dejamos el dato a evaluar/comparar, en este caso, la calidad
predictors_col = ["fixed acidity", "volatile acidity", "citric acid", "residual sugar", "chlorides", "free sulfur dioxide", "density", "pH", "sulphates", "alcohol"]
target_col = ['quality']

# %%
predictors = data[predictors_col]
target = data[target_col]

# %%
predictors
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
target
# Out:
#       quality
# 0           5
# 1           5
# 2           5
# 3           6
# 4           5
# ...       ...
# 1594        5
# 1595        6
# 1596        6
# 1597        5
# 1598        6
#
# [1599 rows x 1 columns]

# %%
#Hallamos la correlacion entre las variables predictoras
corr = predictors.corr()
corr
# Out:
#                      fixed acidity  volatile acidity  citric acid  \
# fixed acidity             1.000000         -0.256131     0.671703
# volatile acidity         -0.256131          1.000000    -0.552496
# citric acid               0.671703         -0.552496     1.000000
# residual sugar            0.114777          0.001918     0.143577
# chlorides                 0.093705          0.061298     0.203823
# free sulfur dioxide      -0.153794         -0.010504    -0.060978
# density                   0.668047          0.022026     0.364947
# pH                       -0.682978          0.234937    -0.541904
# sulphates                 0.183006         -0.260987     0.312770
# alcohol                  -0.061668         -0.202288     0.109903
#
#                      residual sugar  chlorides  free sulfur dioxide   density  \
# fixed acidity              0.114777   0.093705            -0.153794  0.668047
# volatile acidity           0.001918   0.061298            -0.010504  0.022026
# ...

# %%
#Los valores cercanos a uno, nos indica una alta correlacion directa, de lo contrario los cercanos a menos uno, indica una correlacion inversa.

# %%
#Realizamos un mapa de calor con la misma informacion de correlacion
sns.heatmap(corr)
plt.show()

# %%
#En este caso visulizamos exactamente lo mismo que en el anterior, solo que para este caso, a mayor correlacion directa, su color sera mas claro,
#caso contrario seria si su correlacion es inversa, se reflejaria con un color mas oscuro

# %%
#Dividimos los datos en dos grupos para empezar con el arbol de decision
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.21, random_state=13)

# %%
#Creamos el arbol de decision
tree = DecisionTreeClassifier()

# %%
#Con los datos train o entrenamiento, empezamos a darle intruccion e informacion al arbol
arbol = tree.fit(X_train, y_train)

# %%
#Visualizamos el arbol de decision con su grafica resultante
plot_tree(arbol)
# Out:
# [Text(0.4880771936711642, 0.9782608695652174, 'x[9] <= 10.525\ngini = 0.646\nsamples = 1263\nvalue = [9, 45, 526, 510, 161, 12]'),
#  Text(0.16034344467276676, 0.9347826086956522, 'x[8] <= 0.535\ngini = 0.547\nsamples = 760\nvalue = [6, 29, 441, 256, 28, 0]'),
#  Text(0.025537634408602152, 0.8913043478260869, 'x[1] <= 0.335\ngini = 0.363\nsamples = 181\nvalue = [2, 13, 142, 23, 1, 0]'),
#  Text(0.013234077750206782, 0.8478260869565217, 'x[4] <= 0.082\ngini = 0.562\nsamples = 11\nvalue = [0, 1, 4, 6, 0, 0]'),
#  Text(0.009925558312655087, 0.8043478260869565, 'x[2] <= 0.375\ngini = 0.406\nsamples = 8\nvalue = [0, 1, 1, 6, 0, 0]'),
#  Text(0.006617038875103391, 0.7608695652173914, 'x[2] <= 0.29\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.0033085194375516956, 0.717391304347826, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.009925558312655087, 0.717391304347826, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
# ...

# %%
#Hacemos algunas predicciones de los datos
predicciones = arbol.predict(X_test)

# %%
predicciones
# Out:
# array([6, 6, 5, 5, 6, 5, 5, 8, 5, 5, 5, 6, 5, 7, 7, 5, 6, 5, 5, 7, 5, 6,
#        6, 5, 5, 5, 5, 6, 5, 6, 6, 6, 5, 6, 5, 6, 5, 5, 7, 7, 6, 5, 6, 6,
#        4, 5, 6, 5, 6, 6, 5, 5, 6, 5, 7, 6, 5, 8, 4, 5, 5, 5, 5, 7, 7, 7,
#        6, 5, 5, 6, 6, 5, 7, 6, 6, 5, 5, 5, 5, 6, 6, 6, 6, 5, 5, 5, 7, 5,
#        7, 6, 5, 6, 5, 6, 6, 6, 6, 5, 6, 5, 6, 5, 5, 5, 6, 6, 6, 6, 5, 7,
#        6, 7, 6, 6, 6, 6, 6, 7, 5, 5, 5, 5, 5, 6, 6, 5, 5, 5, 6, 7, 6, 5,
#        5, 7, 5, 5, 7, 5, 6, 7, 5, 5, 6, 6, 7, 4, 6, 6, 5, 5, 5, 6, 5, 6,
#        5, 5, 5, 6, 6, 5, 7, 5, 6, 4, 6, 6, 5, 5, 6, 6, 5, 5, 5, 5, 6, 6,
#        5, 5, 5, 5, 5, 6, 6, 6, 5, 5, 6, 6, 5, 5, 5, 5, 5, 5, 7, 5, 6, 7,
#        5, 5, 6, 6, 7, 6, 6, 6, 6, 5, 6, 5, 5, 5, 6, 6, 7, 5, 7, 5, 6, 7,
#        5, 5, 5, 5, 6, 6, 5, 5, 4, 7, 6, 6, 5, 5, 5, 6, 6, 5, 6, 5, 6, 6,
#        5, 5, 5, 6, 7, 5, 5, 5, 6, 6, 5, 5, 7, 7, 5, 7, 5, 6, 6, 6, 7, 5,
#        6, 5, 6, 7, 7, 5, 5, 5, 5, 5, 5, 6, 5, 6, 5, 6, 6, 6, 5, 5, 6, 5,
# ...

# %%
#Examinamos la matriz de confusión
pd.crosstab(np.array([y[0] for y in y_test.values.tolist()]), predicciones, rownames=['actual'], colnames=['predicciones'])
# Out:
# predicciones  4    5   6   7  8
# actual
# 3             0    0   1   0  0
# 4             4    2   1   1  0
# 5             2  115  33   5  0
# 6             2   39  74  12  1
# 7             0    6  11  20  1
# 8             0    1   4   1  0

# %%
#Analizamos la metrica, comparando los valores reales con las predicciones realizadas
accuracy = accuracy_score(y_test,predicciones)
accuracy
# Out:
# 0.6339285714285714
